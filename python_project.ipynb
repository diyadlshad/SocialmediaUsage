# %%
import pandas as pd
import numpy as np
mydata=pd.read_csv('socialmediausage.csv')
mydata.tail(10)
mydata.hist(figsize=(30,30))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':' social media usage'}>],
#        [<AxesSubplot:title={'center':'education level'}>,
#         <AxesSubplot:title={'center':'Unnamed: 6'}>],
#        [<AxesSubplot:title={'center':'Unnamed: 7'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
import seaborn as sns
#sns.boxplot(x="Gender" , y=" soical media usage", data=mydata)
sns.distplot(mydata['Age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
corr = mydata.corr()

sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
corr = mydata.corr()

sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
mydata.hist(by='Gender',column = ' social media usage')

mydata.hist(by=' social media',column = 'education level ', figsize=(20,30))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13480\586266052.py in <module>
#       1 mydata.hist(by='Gender',column = ' social media usage')
#       2
# ----> 3 mydata.hist(by=' social media',column = 'education level ', figsize=(20,30))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     224     """
#     225     plot_backend = _get_plot_backend(backend)
# --> 226     return plot_backend.hist_frame(
#     227         data,
#     228         column=column,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
# ...
